# %% [markdown]
# # Object Placing

# %% [markdown]
# docker run -it -v /DATA/disk1/chenziyi/virtualhome/docker/unity_vol:/unity_vol/ -p 8001:8001 vm /bin/bash

# %% [markdown]
# xvfb-run --auto-servernum --server-args="-screen 0 640x480x24" /unity_vol/linux_exec.v2.3.0.x86_64 -batchmode -http-port=8081

# %%
from utils_demo import *
from utils_view import *
import numpy as np
import os
import time
np.set_printoptions(suppress=True)

from unity_simulator.comm_unity import UnityCommunication

comm = UnityCommunication(port = '8081')

# %%
import json
with open('/DATA/disk1/chenziyi/virtualhome/virtualhome/resources/object_script_placing.json') as f:
    objs = json.load(f)

# %%
{'cups':['wine_glass',"mug",]},
{'toys':['deck_of_cards']},
{'mop_bucket':['mop_bucket']},
{'shoes':['shoes']},
{'computer_accessories': ['laptop', 'cpuscreen','computer', 'printer', 'keyboard', 'mouse', 'mousemat']},
{"Cutting_tool": ["cuttingboard", "cutting_board", "knifeblock"]},
{'papers': ['book','magazine','folder', 'notes', 'mail','novel','diary','printing_paper',]},
{'food': ["bananas", "salad", "cupcake", "crackers", "pancake", "chocolatesyrup",'food_onion','food_lemon','food_jam','food_hamburger',
    "cutlets", "cereal", "breadslice", "pie", "mincedmeat", "apple", "whippedcream", "pear", 'food_peanut_butter', 'food_food',
    "peach", "pudding", "plum", "lime", "candybar", "poundcake", "salmon", "carrot", 'food_kiwi','food_steak','food_bacon',
    'food_orange','food_snack','food_cereal','food_noodles','food_bread','food_donut','food_pizza','food_egg',
    'food_chicken','food_ice_cream','food_potato','food_turkey','food_rice','food_sugar','food_fruit','food_cake','food_cheese',
    'food_vegetable','food_salt','food_dessert','food_fish','food_butter',
    "chips", "candle", "chicken", "creamybuns", "facecream", "bellpepper", "food_oatmeal",'dough',]},
{"stationery":['crayon', 'glue', 'pen',]},
{"beverage": ["juice", "milk", "alcohol",'coffee', 'wine']},
{"Utensile":["plate","cutleryfork","mug","cutleryknife", 'wooden_spoon','spoon',]},
{"Cookware": ["fryingpan","cookingpot"]},
{"cleaning_supplies":["washingsponge","dishwasher", "condimentshaker", "condimentbottle", "dishwashingliquid","cleaning_solution",'cleaning_bottle',]},
{'wash_up_area': ['toothbrush','facecream','toothpaste','waterglass','washingsponge','barsoap', 'face_soap',]}
{"seasoning": ['sauce', ]}
{"controller":['video_game_controller', 'console',]},
{"photo":["photoframe",]}
{'towel_area': ['towelrack','towel']},
{'chair': ['chair']},
{'closet': ['closet', 'closetdrawer',]}
{"cloth":['clothesshirt', 'clothespile','clothes_skirt','clothes_gloves','clothes_dress','clothes_scarf','clothes_underwear','clothes_socks','clothes_pants','clothes_jacket','clothes_hat',]},
{'sink': ['sink']},
{'stall': ['stall']},
{'bathroomcabinet': ['bathroomcabinet']},
{'garbagecan': ['garbagecan']},
{'toiletpaper': ['toiletpaper']},
{'washingmachine': ['washingmachine']},
{'toilet': ['toilet']},
{'bathroomcounter': ['bathroomcounter']},
{'bathtub': ['bathtub']},
{'curtains': ['curtains']},
{'faucet': ['faucet']},
{'deodorant': ['deodorant']},
{'bath_area': ['slippers','hairproduct']},
{'ceilingfan': ['ceilingfan']},
{'pillow': ['pillow']},
{'orchid': ['orchid']},
{'bookshelf': ['bookshelf']},
{'garbagecan': ['garbagecan']},
{'walllamp': ['walllamp']},
{'wallpictureframe': ['wallpictureframe']},
{'coffeetable': ['coffeetable']},
{'desk': ['desk']},
{'curtains': ['curtains']},
{'sofa': ['sofa']},
{'cabinet': ['cabinet']},
{'window': ['window']},
{'tv': ['tv', 'tvstand','remotecontrol']},
{'papers': ['book','magazine','folder', "photoframe"]},
{'computer_accessories': ['cpuscreen','computer', 'printer', 'keyboard', 'mouse', 'mousemat']},
{'tv': ['tv', 'tvstand','remotecontrol']},
{'coffeetable': ['coffeetable']},
{'desk': ['desk']},

{'sofa': ['sofa']},
{'cabinet': ['cabinet']},
{'window': ['window']},
{'bed': ['bed', 'pillow']},
{'stove': ['stove']},
{'sink': ['sink']},
{'kitchencounterdrawer': ['kitchencounterdrawer']},
{'garbagecan': ['garbagecan']},
{'kitchentable': ['kitchentable']},
{'oventray': ['oventray']},
{'toaster': ['toaster']},
{'stovefan': ['stovefan']},
{'kitchencounter': ['kitchencounter']},
{'kitchencabinet': ['kitchencabinet']},


{"Cutting_tool": ["cuttingboard","knifeblock"]},
{"Utensile":["plate","cutleryfork","mug","cutleryknife"]},

# %%
with open('/DATA/disk1/chenziyi/virtualhome/virtualhome/resources/properties_data_unity.json') as f:
    obj_unity = list(json.load(f).keys())

# %%
"amplifier":['amplifier','projector','speaker',],

'game':['boardgame','game',],
"broom":['broom','dustpan',],
"lights":['ceilinglamp','nightstand','tablelamp',],
"stationery":['cards', 'crayons','pen',],
'cellphone':['wallphone','cellphone',],
'toy':['teddybear','toy','beer',],
'shelf':['shelf','wallshelf',],

'bucket': ['bucket'],
'cat': ['cat'],
'clock': ['clock'],
'globe': ['globe'],
'glasses': ['glasses'],
'guitar': ['guitar'],
'kettle': ['kettle'],
'microwave': ['microwave'],
'napkin': ['napkin'],
'papertowel': ['papertowel'],
'perfume': ['perfume'],
'powersocket': ['powersocket'],
'radio': ['radio'],
'rug': ['rug'],
'shelfsoapset': ['shelfsoapset'],
'soapset': ['soapset'],
'papertray': ['papertray'],
'standingmirror': ['standingmirror'],
'vase': ['vase'],
'box': ['box'],

# %%
kitchen = [
    {'stove': ['stove']},
    {'sink': ['sink']},
    {'kitchencounterdrawer': ['kitchencounterdrawer']},
    {'garbagecan': ['garbagecan']},
    {'kitchentable': ['kitchentable','diningtable',]},
    {'oventray': ['oventray']},
    {'toaster': ['toaster']},
    {'stovefan': ['stovefan']},
    {'kitchencounter': ['kitchencounter']},
    {'kitchencabinet': ['kitchencabinet']},
    {"beverage": ["juice", "milk", "alcohol", 'milkshake','wine',]},
    {"cleaning_supplies":["washingsponge","dishwasher", "condimentshaker", "condimentbottle", "dishwashingliquid"]},
    {"Cookware": ["fryingpan","cookingpot"]},
    {"Cutting_tool": ["cuttingboard","knifeblock",'board','chefknife','painkillers','spoon',]},
    {"Utensile":["plate","cutleryfork","cutleryknife", 'painkillers',]},
    {'food': ["bananas", "salad", "cupcake", "crackers", "pancake", "chocolatesyrup",'bread',
    "cutlets", "cereal", "breadslice", "pie", "mincedmeat", "apple", "whippedcream", "pear", 'cucumber',
    "peach", "pudding", "plum", "lime", "candybar", "poundcake", "salmon", "carrot", 'chinesefood',
    'donut','lemon','orange','potato','sundae','tomato','watermelon',
    "chips", "candle", "chicken", "creamybuns", "facecream", "bellpepper"]},
    {"cup":['wineglass',"mug",]}
    ]
bedroom = [
    {'tv': ['tv', 'tvstand','remotecontrol', 'walltv',]},
    {'coffeetable': ['coffeetable']},
    {'desk': ['desk']},
    {'chair': ['chair']},
    {'sofa': ['sofa','bench',]},
    {'cabinet': ['cabinet']},
    {'window': ['window']},
    {'bed': ['bed', 'pillow']},
    {'closet': ['closet', 'hanger', 'closetdrawer', 'clothesshirt', 'clothespile','clothespants',]}
    ]
livingroom = [
    {'ceilingfan': ['ceilingfan']},
    {'pillow': ['pillow']},
    {'orchid': ['orchid']},
    {'bookshelf': ['bookshelf']},
    {'garbagecan': ['garbagecan']},
    {'walllamp': ['walllamp']},
    {'wallpictureframe': ['wallpictureframe']},
    {'coffeetable': ['coffeetable']},
    {'desk': ['desk']},
    {'curtains': ['curtains']},
    {'chair': ['chair']},
    {'sofa': ['sofa']},
    {'cabinet': ['cabinet']},
    {'window': ['window']},
    {'tv': ['tv', 'tvstand','remotecontrol']},
    {'papers': ['book','magazine','folder', "photoframe",'journal','notes',]},
    {'computer_accessories': ['cpuscreen','computer', 'printer', 'keyboard', 'mouse', 'mousemat']},
    {'sports':['sportsball','balanceball','longboard']}
]
bathroom = [
    {'sink': ['sink']},
    {'stall': ['stall']},
    {'bathroomcabinet': ['bathroomcabinet']},
    {'garbagecan': ['garbagecan']},
    {'toiletpaper': ['toiletpaper']},
    {'washingmachine': ['washingmachine']},
    {'toilet': ['toilet']},
    {'bathroomcounter': ['bathroomcounter']},
    {'bathtub': ['bathtub','jacuzzi',]},
    {'curtains': ['curtains']},
    {'faucet': ['faucet']},
    {'deodorant': ['deodorant']},
    {'bath_area': ['slippers','hairproduct']},
    {'towel_area': ['towelrack','towel']},
    {'wash_up_area': ['toothbrush','facecream','lotionbottle','toothpaste','waterglass','washingsponge','barsoap']}]
import json
kitchen = {k:v for i in kitchen for k,v in i.items()}
bathroom = {k:v for i in bathroom for k,v in i.items()}
bedroom = {k:v for i in bedroom for k,v in i.items()}
livingroom = {k:v for i in livingroom for k,v in i.items()}
furn_cluster = {'bedroom':bedroom,
                'bathroom': bathroom,
                'livingroom':livingroom,
                'kitchen': kitchen}
with open('furniture_cluster.json', 'w') as f:
    json.dump(furn_cluster, f, indent=4)

# %%
furn_cluster = {'bedroom': {
    'kettle': ['kettle'],
      'ceilingfan': ['ceilingfan'],
  'orchid': ['orchid'],
  'bookshelf': ['bookshelf'],
  'garbagecan': ['garbagecan'],
  'walllamp': ['walllamp'],
  'wallpictureframe': ['wallpictureframe'],
  'curtains': ['curtains'],
  'tv': ['tv', 'tvstand', 'remotecontrol'],
  'papers': ['book', 'magazine', 'folder', 'photoframe', 'journal', 'notes'],
  'computer_accessories': ['cpuscreen',
   'computer',
   'printer',
   'keyboard',
   'mouse',
   'mousemat'],
  'coffeetable': ['coffeetable'],
  'desk': ['desk'],
  'chair': ['chair'],
  'sofa': ['sofa', 'bench'],
  'cabinet': ['cabinet'],
  'window': ['window'],
  'bed': ['bed', 'pillow'],
  'closet': ['closet','hanger','closetdrawer','clothesshirt','clothespile','clothespants'],
  "amplifier":['amplifier','projector','speaker',],
  "broom":['broom','dustpan',],
"lights":['nightstand','tablelamp',],
'cellphone':['wallphone','cellphone',],
'clock': ['clock'],
'shelf':['shelf','wallshelf',],
'napkin': ['napkin'],
'papertowel': ['papertowel'],
'perfume': ['perfume'],
'powersocket': ['powersocket'],
'cat': ['cat'],
'standingmirror': ['standingmirror'],
'vase': ['vase'],
'box': ['box'],
'rug': ['rug'],
'cup': ['wineglass', 'mug'],
'game':['boardgame','game',],
'toy':['teddybear','toy','beer',],
"stationery":['cards', 'crayons','pen',],
'globe': ['globe'],
'glasses': ['glasses'],
'guitar': ['guitar'],
'papertray': ['papertray'],
'radio': ['radio'],
'cup': ['wineglass', 'mug'],
'food': ['bananas',
   'salad',
   'cupcake',
   'crackers',
   'pancake',
   'chocolatesyrup',
   'bread',
   'cutlets',
   'cereal',
   'breadslice',
   'pie',
   'mincedmeat',
   'apple',
   'whippedcream',
   'pear',
   'cucumber',
   'peach',
   'pudding',
   'plum',
   'lime',
   'candybar',
   'poundcake',
   'salmon',
   'carrot',
   'chinesefood',
   'donut',
   'lemon',
   'orange',
   'potato',
   'sundae',
   'tomato',
   'watermelon',
   'chips',
   'candle',
   'chicken',
   'creamybuns',
   'facecream',
   'bellpepper'],
  },

'bathroom': {
  'sink': ['sink'],
  'stall': ['stall'],
  'bathroomcabinet': ['bathroomcabinet'],
  'garbagecan': ['garbagecan'],
  'toiletpaper': ['toiletpaper'],
  'washingmachine': ['washingmachine'],
  'toilet': ['toilet'],
  'bathroomcounter': ['bathroomcounter'],
  'bathtub': ['bathtub', 'jacuzzi'],
  'curtains': ['curtains'],
  'faucet': ['faucet'],
  'deodorant': ['deodorant'],
  'bath_area': ['slippers', 'hairproduct'],
  'towel_area': ['towelrack', 'towel'],
  'wash_up_area': ['toothbrush','facecream','lotionbottle','toothpaste','waterglass','washingsponge','barsoap','soapset'],
  'shelfsoapset': ['shelfsoapset'],
  "broom":['broom','dustpan',],
"lights":['nightstand','tablelamp',],
'cellphone':['wallphone','cellphone',],
'clock': ['clock'],
'shelf':['shelf','wallshelf',],
'napkin': ['napkin'],
'papertowel': ['papertowel'],
'perfume': ['perfume'],
'powersocket': ['powersocket'],
'cat': ['cat'],
'standingmirror': ['standingmirror'],
'vase': ['vase'],
'box': ['box'],
'rug': ['rug'],
'cup': ['wineglass', 'mug'],
'bucket': ['bucket'],
'closet': ['closet','hanger','closetdrawer','clothesshirt','clothespile','clothespants'],

  },

'livingroom': {
    'kettle': ['kettle'],
  'ceilingfan': ['ceilingfan'],
  'pillow': ['pillow'],
  'orchid': ['orchid'],
  'bookshelf': ['bookshelf'],
  'garbagecan': ['garbagecan'],
  'walllamp': ['walllamp'],
  'wallpictureframe': ['wallpictureframe'],
  'coffeetable': ['coffeetable'],
  'desk': ['desk'],
  'curtains': ['curtains'],
  'chair': ['chair'],
  'sofa': ['sofa'],
  'cabinet': ['cabinet'],
  'window': ['window'],
  'tv': ['tv', 'tvstand', 'remotecontrol'],
  'papers': ['book', 'magazine', 'folder', 'photoframe', 'journal', 'notes'],
  'computer_accessories': ['cpuscreen',
   'computer',
   'printer',
   'keyboard',
   'mouse',
   'mousemat'],
  'sports': ['sportsball', 'balanceball', 'longboard'],
  "amplifier":['amplifier','projector','speaker',],
  "broom":['broom','dustpan',],
"lights":['nightstand','tablelamp',],
'cellphone':['wallphone','cellphone',],
'clock': ['clock'],
'shelf':['shelf','wallshelf',],
'napkin': ['napkin'],
'papertowel': ['papertowel'],
'perfume': ['perfume'],
'powersocket': ['powersocket'],
'cat': ['cat'],
'standingmirror': ['standingmirror'],
'vase': ['vase'],
'box': ['box'],
'rug': ['rug'],
'game':['boardgame','game',],
'toy':['teddybear','toy','beer',],
"stationery":['cards', 'crayons','pen',],
'globe': ['globe'],
'glasses': ['glasses'],
'guitar': ['guitar'],
'papertray': ['papertray'],
'radio': ['radio'],
'cup': ['wineglass', 'mug'],
'food': ['bananas',
   'salad',
   'cupcake',
   'crackers',
   'pancake',
   'chocolatesyrup',
   'bread',
   'cutlets',
   'cereal',
   'breadslice',
   'pie',
   'mincedmeat',
   'apple',
   'whippedcream',
   'pear',
   'cucumber',
   'peach',
   'pudding',
   'plum',
   'lime',
   'candybar',
   'poundcake',
   'salmon',
   'carrot',
   'chinesefood',
   'donut',
   'lemon',
   'orange',
   'potato',
   'sundae',
   'tomato',
   'watermelon',
   'chips',
   'candle',
   'chicken',
   'creamybuns',
   'facecream',
   'bellpepper'],
  },

 'kitchen': {
  'stove': ['stove'],
  'kettle': ['kettle'],
  'sink': ['sink'],
  'kitchencounterdrawer': ['kitchencounterdrawer'],
  'garbagecan': ['garbagecan'],
  'kitchentable': ['kitchentable', 'diningtable'],
  'oventray': ['oventray'],
  'toaster': ['toaster'],
  'stovefan': ['stovefan'],
  'kitchencounter': ['kitchencounter'],
  'kitchencabinet': ['kitchencabinet'],
  'beverage': ['juice', 'milk', 'alcohol', 'milkshake', 'wine'],
  'cleaning_supplies': ['washingsponge','dishwasher','dishwashingliquid'],
  'condiment': ['condimentshaker','condimentbottle',],
  'Cookware': ['fryingpan', 'cookingpot'],
  'cutting_tool': ['cuttingboard','knifeblock','board','chefknife','painkillers','spoon'],
  'Utensile': ['plate', 'cutleryfork', 'cutleryknife', 'painkillers'],
  'microwave': ['microwave'],
  'food': ['bananas',
   'salad',
   'cupcake',
   'crackers',
   'pancake',
   'chocolatesyrup',
   'bread',
   'cutlets',
   'cereal',
   'breadslice',
   'pie',
   'mincedmeat',
   'apple',
   'whippedcream',
   'pear',
   'cucumber',
   'peach',
   'pudding',
   'plum',
   'lime',
   'candybar',
   'poundcake',
   'salmon',
   'carrot',
   'chinesefood',
   'donut',
   'lemon',
   'orange',
   'potato',
   'sundae',
   'tomato',
   'watermelon',
   'chips',
   'candle',
   'chicken',
   'creamybuns',
   'facecream',
   'bellpepper'],
  'cup': ['wineglass', 'mug'],
  "broom":['broom','dustpan',],
"lights":['nightstand','tablelamp',],
'cellphone':['wallphone','cellphone',],
'clock': ['clock'],
'shelf':['shelf','wallshelf',],
'napkin': ['napkin'],
'papertowel': ['papertowel'],
'perfume': ['perfume'],
'powersocket': ['powersocket'],
'cat': ['cat'],
'standingmirror': ['standingmirror'],
'vase': ['vase'],
'box': ['box'],
'rug': ['rug'],}}



with open('object_cluster.json', 'w') as f:
    json.dump(furn_cluster, f, indent=4)
